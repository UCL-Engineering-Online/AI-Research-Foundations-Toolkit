# %% [markdown]
# > <p><small>This notebook is made available subject to the licence and terms set out in <a href="https://creativecommons.org/licenses/by/4.0">https://creativecommons.org/licenses/by/4.0</a>.</small></p>

# %% [markdown]
# <img src="https://pub-bba109a9a6ac49e3b428cdca19c34363.r2.dev/LT%20-%20Session%207.jpg">

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # 7.6 AI Long Activity 1 - Lab: Compute, Memory and Efficiency (Student)
#
# Develop an operational understanding of why training can become slow or infeasible.
#
# 60 minutes

# %% [markdown]
# ## Overview
# You will estimate compute and memory requirements, investigate scaling behaviour, and relate simple models to practical optimization strategies.

# %% [markdown]
# ### What you'll learn:
#
# - Explain how compute scales with model size and sequence length.
# - Decompose memory into parameters and activations and predict how each term scales.
# - Diagnose compute-, memory-, and data-bottlenecks from signals.
# - Apply mitigation strategies and justify trade-offs such as time vs. memory, and accuracy vs. latency.

# %% [markdown]
# > 💻 **Your tasks:**
# > 1. Complete the scaffolded functions.
# > 2. Run the experiments.
# > 3. Interpret the results.
# > 4. Reflect on how efficiency techniques affect scaling.

# %% [markdown]
# ---
# > **Protocol:**
# > Predict → Run → Observe → Reflect

# %% [markdown]
# ## Step 1 – Compute model
#
# Key idea:
# Inference and training become more expensive as sequence length increases.
#
# Predict:
# If you double the sequence length, what do you think happens to compute cost?

# %%
# Step 1
# Complete the function below.
# Hint:
# - params: number of model parameters
# - seq_len: sequence length
# - Return an estimated compute cost.

def compute_cost(params: int, seq_len: int):
    """Estimate compute cost for a toy Transformer model."""
    # Add your code here.
    pass

# %% [markdown]
# ## Step 2 – Scaling sweep

# %%
# Print compute for seq in [100, 1000, 10000].
# Enter your code here.

# %% [markdown]
# ## Step 3 – Memory decomposition
#
# Key idea:
# GPU memory usage comes from:
# - Model parameters.
# - Activations stored during computation.
#
# In real transformer systems, activation memory often scales with:
# batch_size × sequence_length × number_of_layers × d_model
#
# Predict:
# Which variable do you think increases memory usage most rapidly?

# %%
# Step 3
# Complete the functions below.

def parameter_memory(num_params: int, bytes_per_param: int):
    """Return memory used by model parameters (bytes)."""
    # Add your code here.
    pass

def activation_memory(batch_size:int,max_length:int,num_layers:int,d_model:int,bytes_per_param:int):
    """Estimate activation memory (bytes)."""
    # total_bytes = batch_size * max_length * num_layers * d_model * bytes_per_param
    # Add your code here.
    pass

def total_memory(...):
    # Add your code here.
    pass

# %% [markdown]
# ## Step 4 – Batch impact

# %%
# Loop over batch sizes and print memory.
# Enter your code here.

# %% [markdown]
# ## Step 5 – Sequence impact

# %%
# Loop over sequence lengths and print memory.
# Enter your code here.

# %% [markdown]
# ## Step 6 – Bottleneck diagnosis
# Classify A/B/C with evidence.

# %%
# Enter your code here.

# %% [markdown]
# ## Step 7 – Gradient accumulation

# %% [markdown]
# ## Practical reflection
#
# In real-world AI systems, engineers often face trade-offs between:
# - Model size.
# - Speed.
# - Memory usage.
# - Hardware cost.
#
# For example, a local start-up may be able to run inference on a small GPU, but training a large model may require expensive hardware and optimization techniques such as:
# - Mixed precision (bfloat16 / fp16).
# - Gradient checkpointing.
# - Reduced batch size.
# - Quantization.

# %%
# Define effective_batch and test it.
# Enter your code here.

# %% [markdown]
# ## Step 8 – Feasibility (16 GB)
# Estimate memory for given params.

# %%
# Enter your code here.

# %% [markdown]
# ## Step 9 – Decision task
# Choose two changes and justify (≥2 constraints).

# %%
# Enter your code here.

# %% [markdown]
# ## Final reflection
# - What dominates memory?
# - What dominates compute?
# - What would you change first under a 16 GB constraint?
