# %% [markdown]
# > <p><small>This notebook is made available subject to the licence and terms set out in <a href="https://creativecommons.org/licenses/by/4.0">https://creativecommons.org/licenses/by/4.0</a>.</small></p>

# %% [markdown]
# <img src="https://pub-bba109a9a6ac49e3b428cdca19c34363.r2.dev/LT%20-%20Session%203.jpg">

# %% [markdown]
# # 3.7 AI Long Activity 2 - Lab: Neural Network Training (Student)
#
# Train a small neural network on a simple dataset and observe how overfitting occurs.
#
# 60 minutes

# %% [markdown]
# ## Overview
#
# In this lab, you will train and compare several neural networks on a small two-dimensional dataset.
#
# The goal is to make overfitting visible. Accuracy numbers are useful, but decision boundary plots help you see how a model separates the two classes.
#
# You will:
# - Generate a noisy dataset.
# - Split it into training and test sets.
# - Train a high-capacity model.
# - Train a smaller model.
# - Train a regularized model.
# - Compare model behaviour using accuracy, loss curves, and decision boundaries.

# %% [markdown]
# ### What you'll learn:
#
# - Explain overfitting and generalization conceptually.
# - Interpret training and test performance.
# - Relate model complexity to bias and variance.

# %% [markdown]
# ---
# > 💻 **Your task:**
# > Complete the notebook step by step.
# > 1. Load the libraries and generate the dataset.
# > 2. Split the data into training and test sets.
# > 3. Use the provided plotting function to visualise decision boundaries.
# > 4. Train a high-capacity neural network.
# > 5. Plot the training loss.
# > 6. Train a smaller neural network.
# > 7. Train a regularized neural network.
# > 8. Run one guided experiment by changing model settings.
# > 9. Compare the models and write a short reflection.

# %% [markdown]
# > ℹ️ **Info**
# > A model that performs extremely well on training data but poorly on test data is likely to be overfitting. In this activity, the decision boundary plot should help you see this visually.

# %% [markdown]
# ## Step 1 — Imports and setup
#
# Run the cell below to import the required libraries.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_moons
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ## Step 2 — Generate a noisy dataset
#
# This dataset contains two classes arranged in curved shapes. Noise makes the task more realistic and creates opportunities for overfitting.
#
# > 💭 **Reflection**
# > Before training any model, do you expect a large neural network to fit this dataset better or worse than a smaller one? Why?

# %%
X, y = make_moons(
    n_samples=150,
    noise=0.3,
    random_state=42,
)

plt.figure(figsize=(6, 4))
plt.scatter(
    X[:, 0],
    X[:, 1],
    c=y,
    cmap="coolwarm",
    edgecolor="k",
)

plt.title("Noisy moon dataset")
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

# %% [markdown]
# ## Step 3 — Split the data
#
# The training set is used to fit the model. The test set is used to check generalization on unseen examples.
#
# > ℹ️ **Info**
# > If a model is evaluated only on the data used for training, its performance may look better than it really is.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
)

print("Training size:", len(X_train))
print("Test size:", len(X_test))

# %% [markdown]
# ## Step 4 — Helper function to visualize decision boundaries
#
# Run the cell below. This helper function is provided so that the focus stays on model behavior rather than plotting code.

# %%
def plot_decision_boundary(model, X, y, title):
    """Plot a model's predicted decision regions together with data points.

    Args:
        model: A fitted scikit-learn classifier with a predict method.
        X: A two-column array containing input features.
        y: A one-dimensional array containing class labels.
        title: Title to display above the plot.
    """
    x_min = X[:, 0].min() - 0.5
    x_max = X[:, 0].max() + 0.5
    y_min = X[:, 1].min() - 0.5
    y_max = X[:, 1].max() + 0.5

    xx, yy = np.meshgrid(
        np.linspace(x_min, x_max, 300),
        np.linspace(y_min, y_max, 300),
    )

    grid = np.c_[xx.ravel(), yy.ravel()]
    predictions = model.predict(grid)
    predictions = predictions.reshape(xx.shape)

    plt.figure(figsize=(6, 4))
    plt.contourf(
        xx,
        yy,
        predictions,
        alpha=0.25,
        cmap="coolwarm",
    )
    plt.scatter(
        X[:, 0],
        X[:, 1],
        c=y,
        cmap="coolwarm",
        edgecolor="k",
    )

    plt.title(title)
    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.show()

# %% [markdown]
# ## Step 5 — Model 1: high-capacity network
#
# A high-capacity model has many parameters and can learn complex boundaries.
#
# Complete the scaffolded code below.
#
# > 💭 **Reflection**
# > Do you expect this model to underfit, generalize well, or overfit? Explain your prediction before running the cell.

# %%
# Define a large neural network.
model_big = MLPClassifier(
    hidden_layer_sizes=(100, 100),
    max_iter=2000,
    random_state=42,
)

# Train the model.
# Add your code here.

# Compute training accuracy.
train_acc_big = accuracy_score(
    y_train,
    # Add your code here.
)

# Compute test accuracy.
test_acc_big = accuracy_score(
    y_test,
    # Add your code here.
)

print("High-capacity model")
print("Training accuracy:", train_acc_big)
print("Test accuracy:", test_acc_big)

# Plot the decision boundary on the training set.
# Add your code here.

# Plot the decision boundary on the test set.
# Add your code here.

# %% [markdown]
# ## Step 6 — Observe training loss
#
# Models are trained by minimizing a loss function. The attribute `loss_curve_` stores the training loss over optimization iterations.
#
# > ℹ️ **Info**
# > Training is an iterative process. The model repeatedly updates its parameters to reduce the loss.

# %%
# Display the first few values of the training loss curve.
# Add your code here.

# Plot the full loss curve.
plt.figure(figsize=(6, 4))

# Add your code here.

plt.title("Training loss over iterations")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# ## Step 7 — Model 2: smaller network
#
# A smaller network has less capacity. It may not fit the training data as closely, but it can sometimes generalize better.
#
# Complete the scaffolded code below.

# %%
# Define a smaller neural network.
model_small = MLPClassifier(
    hidden_layer_sizes=(20,),
    max_iter=2000,
    random_state=42,
)

# Train the model.
# Add your code here.

# Compute training accuracy.
train_acc_small = accuracy_score(
    y_train,
    # Add your code here.
)

# Compute test accuracy.
test_acc_small = accuracy_score(
    y_test,
    # Add your code here.
)

print("Smaller model")
print("Training accuracy:", train_acc_small)
print("Test accuracy:", test_acc_small)

# Plot the decision boundary on the test set.
# Add your code here.

# %% [markdown]
# ## Step 8 — Model 3: regularized network
#
# Regularization discourages the model from fitting noise too closely. In `MLPClassifier`, the `alpha` parameter controls L2 regularization.
#
# Complete the scaffolded code below.
#
# > 💭 **Reflection**
# > What effect do you expect regularization to have on training accuracy, test accuracy, and the smoothness of the decision boundary?

# %%
# Define a regularised large neural network.
model_reg = MLPClassifier(
    hidden_layer_sizes=(100, 100),
    alpha=0.1,
    max_iter=2000,
    random_state=42,
)

# Train the model.
# Add your code here.

# Compute training accuracy.
train_acc_reg = accuracy_score(
    y_train,
    # Add your code here.
)

# Compute test accuracy.
test_acc_reg = accuracy_score(
    y_test,
    # Add your code here.
)

print("Regularized large model")
print("Training accuracy:", train_acc_reg)
print("Test accuracy:", test_acc_reg)

# Plot the decision boundary on the test set.
# Add your code here.

# %% [markdown]
# ## Step 9 — Guided experiment
#
# Change one setting at a time. This helps identify which change caused which effect.
#
# Try at least one of the following:
# - change `hidden_layer_sizes`
# - change `alpha`
# - change `max_iter`
#
# The scaffolded cell below gives placeholders so that you do not need to write the experiment from scratch.

# %%
# Choose experiment settings.
hidden = (50, 50)
alpha = 0.01
max_iter = 2000

# Define the experimental model.
model_exp = MLPClassifier(
    hidden_layer_sizes=hidden,
    alpha=alpha,
    max_iter=max_iter,
    random_state=42,
)

# Train the model.
# Add your code here.

# Compute training and test accuracy.
train_acc_exp = accuracy_score(
    y_train,
    # Add your code here.
)

test_acc_exp = accuracy_score(
    y_test,
    # Add your code here.
)

print("Experiment model")
print("hidden_layer_sizes =", hidden)
print("alpha =", alpha)
print("max_iter =", max_iter)
print("Training accuracy:", train_acc_exp)
print("Test accuracy:", test_acc_exp)

# Plot the decision boundary on the test set.
# Add your code here.

# %% [markdown]
# ## Step 10 — Compare your models
#
# Use this section to compare the models numerically.

# %%
print("Summary")
print("-------------------------------")

# Complete each line using the accuracy variables created above.
# Add your code here.

# %% [markdown]
# ## Step 11 — What does training actually do?
#
# The key idea behind gradient descent is:
#
# `w_new = w - η ∇L`
#
# where:
# - `w` = model parameters
# - `η` = learning rate
# - `∇L` = gradient of the loss
#
# The simple example below asks you to implement a few gradient descent steps for the loss `L(w) = (w - 3)^2`.

# %%
def loss(w):
    """Return the value of L(w) = (w - 3)^2."""
    # Add your code here.


def grad(w):
    """Return the gradient of L(w) = (w - 3)^2."""
    # Add your code here.


w = 0.0
eta = 0.1
trajectory = [w]

for _ in range(10):
    # Update w using gradient descent.
    # Add your code here.

    trajectory.append(w)

print("Parameter updates:", trajectory)

plt.figure(figsize=(6, 4))
plt.plot(
    trajectory,
    marker="o",
)
plt.title("Gradient descent towards minimum")
plt.xlabel("Step")
plt.ylabel("w")
plt.show()

# %% [markdown]
# > 💭 **Reflection:**
# > Write a short response to the following questions:
# >
# > 1. Which model had the highest training accuracy?
# > 2. Which model had the best test accuracy?
# > 3. Which model seemed most likely to overfit?
# > 4. How did the decision boundary plots help you understand overfitting?
# > 5. Why can regularization improve generalization even if training accuracy decreases?
# >
# > **Key takeaway**
# > The best model is not always the one that fits the training data most closely. A good model is one that generalizes well to new data.
